# %%
import sys 
sys.path.append("/home/mbelmar/Documentos/Programaçao - Projetos/Projetos/MacroDataHub/src")

# %%
from macrodatahub.application.services.series_service import SeriesService

# %%
Test=SeriesService()

# %%
Test.download(
            Series_name="IPCA", 
            code=r"T/7060/P/all/V/63/C315/all/N1/1", 
            source=r"ibge",
            path='/home/mbelmar/Documentos/Programaçao - Projetos/Projetos/MacroDataHub/data/raw_storage'
        
        )
